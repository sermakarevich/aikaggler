# %% [markdown]
# # Latest Version of this Solution:
# https://www.kaggle.com/code/kaito510/goto-conversion2024-2025-2026-withdirectsub
#
# # How this Solution Works:
# https://gotoconversion.substack.com/p/why-goto_conversion-wins-on-kaggle
